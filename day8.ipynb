# %%
import cv2
import matplotlib.pyplot as plt
import skimage as ski

# %%
img = cv2.imread('Devi.jpg')
img.shape
# Out:
# (1500, 1500, 3)

# %%
plt.imshow(img[:,:,::-1])

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray.shape
# Out:
# (1500, 1500)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
th, img_bin = cv2.threshold(img_gray, 120,255, cv2.THRESH_BINARY)
img_bin.shape
# Out:
# (1500, 1500)

# %%
plt.imshow(img_bin, cmap='gray')

# %%
plt.imshow(img[:200, 200:400,::-1])#, cmap='gray')

# %%
x,y,w,h = (50,150, 180, 140)
plt.imshow(img[y:y+h, x:x+w, ::-1])
plt.show()

x1,y1,x2,y2 = (50,150, 270, 210)
plt.imshow(img[y1:y2, x1:x2, ::-1])
plt.show()

y1,x1,y2,x2 = (50,150, 270, 210)
plt.imshow(img[y1:y2, x1:x2, ::-1])
plt.show()

# %%
x,y,w,h = (50,150, 180, 140)
plt.subplot(1,3,1)
plt.imshow(img[y:y+h, x:x+w, ::-1])

x1,y1,x2,y2 = (50,150, 270, 210)
plt.subplot(1,3,2)
plt.imshow(img[y1:y2, x1:x2, ::-1])

y1,x1,y2,x2 = (50,150, 270, 210)
plt.subplot(1,3,3)
plt.imshow(img[y1:y2, x1:x2, ::-1])

# %%
import cv2
import skimage
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.8.0'

# %%
img1 = plt.imread('download.png')
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
img2 = cv2.imread('download.png')
cv2.imshow('Image', img2)

# %%
img3 = skimage.io.imread('Devi.jpg')
skimage.io.imshow(img3)

# %%
type(img3), type(img2), type(img1)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
img3.shape, img2.shape, img1.shape
# Out:
# ((1500, 1500, 3), (279, 515, 3), (279, 515, 4))

# %%
import numpy as np
r1 = np.random.randint(0,255, (500,500,3))
plt.imshow(r1)

# %%
r2 = np.random.randint(0,255, (50,50))
plt.imshow(r2, cmap='gray')

# %%
img = np.ones((50,50,3), dtype='uint8') * 255
img[:25,:25,1:] = 0         # img[:25,:25,1:] * 0
img[:25,25:,::2] = 0        # img[:25,25:,::2] * 0
img[25:,:25,:2] = 0         # img[25:,:25,:2] * 0
img[25:,25:,2:] = 0         # img[25:,25:,2:] * 0
plt.imshow(img)

# %%
a = [230,100,45]
a[::2]
# Out:
# [230, 45]

# %%
plt.imsave('download.png', img)

# %%
skimage.io.imsave('download.png', img)

# %%
cv2.imwrite('Devi.jpg', img[:,:,::-1])
# Out:
# True

# %%
plt.imshow(img2[:,:,::-1])
plt.axis('off')
plt.show()

# %%
skimage.io.imshow(img2[:,:,::-1])
